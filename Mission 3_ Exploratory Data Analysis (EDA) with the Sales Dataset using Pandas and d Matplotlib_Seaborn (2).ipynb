# %% [markdown]
# # **Mission 3: Exploratory Data Analysis (EDA) with the Sales Dataset using Pandas and d Matplotlib/Seaborn**
#
# ### **Objective:**
#
# The goal of this assignment is to help you apply your knowledge of Python for basic operations, Pandas for data manipulation, and Matplotlib/Seaborn for visualizations. You'll be working with a real-world dataset, and your tasks will include loading the data, performing EDA, and visualising the results.
#
# ###  **Dataset**
#
# The dataset represents transaction data from a retail business, specifically sales data for products sold in various stores. It contains multiple tables that provide insights into sales, invoices, and products. Let’s break down the tables and what they represent:
#
# #### Sales Table:
#
# InvoiceNo: The unique identifier for each invoice (or transaction).
#
# StockCode: A unique identifier for each product.
#
# Quantity: The number of units sold in each transaction.
#
# UnitPrice: The price per unit of the product.
#
# InvoiceDate: The date when the transaction occurred.
#
# #### Invoice Table:
#
# InvoiceNo: The same unique identifier for each invoice, linking the sales data with the invoice details.
#
# Country: The country where the sale was made.
#
# #### Product Table:
#
# StockCode: A unique identifier for each product.
#
# Description: The name or description of the product.
#
# Product_Category: The category the product belongs to (e.g., "Gift", "Sign", "Mug").
#
#
#
# You will need to merge them and perform the following tasks step by step.

# %% [markdown]
# ### Task 1: Load the Excel File
# #### Objective: Import the data from the provided Excel file into Python using Pandas.
#
# Instructions:
#
# 1. Upload the provided excel file into Fabric environment
# 2. Read each sheet of the excel file as a separate dataframe.
# 3. Name the dataframe for sales as df_sales, the dataframe for invoice as df_invoice and the dataframe for product as df_product
# 4. Display the first few rows of each DataFrame to understand its structure.

# %%
### Code Task Here
import pandas as pd

df = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx")
df_sales = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx", sheet_name='Sales')
df_invoice = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx", sheet_name='Invoice')
df_product = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx", sheet_name='Product')

display(df_sales)
display(df_invoice)
display(df_product)

# %% [markdown]
# ### Task 2: Basic Python and Pandas Operations
# #### Objective: Perform basic Python and Pandas operations to manipulate the data.
#
# <mark>Instructions:</mark>
#
# 1. Check for missing values in the Sales DataFrame.
#
# 2. Replace any NaN values in the Sales and UnitPrice columns with 0.
#
# 3. Calculate basic descriptive statistics for the Quantity and UnitPrice columns (mean, median, mode, standard deviation).

# %%
## Code Task 2 here
missing_values = df.isnull()
display(missing_values)

# %%
rows_with_nulls = df[missing_values.any(axis=1)]
display(rows_with_nulls)

# %%
df_filled = df.fillna(0)
display(df_filled.head(10))
display(len(df_filled))
# Out:
# 83277

# %% [markdown]
# --->>> ANOTHER WAY OF DOING THE PROCESS, I HAVE JUST DOUBLE CHECK THE RESULTS THROUGH ANOTHER WAY...

# %%
#OR  ### another way of doing it
filtered_df = df[df['UnitPrice'] .isnull()]
display(filtered_df)

df_Sales_filled = df.fillna({'UnitPrice':0})
display(df_Sales_filled)

# %% [markdown]
# <mark>**--->>>TASK 2 #3 INSTRUCTION**</mark>

# %%
##Calculate basic descriptive statistics for the Quantity and UnitPrice columns (mean, median, mode, standard deviation).
import pandas as pd

df = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx")
df_sales = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx", sheet_name='Sales')

mean_Quantity = df_sales['Quantity'].mean()
median_Quantity = df_sales['Quantity'].median()
mode_Quantity = df_sales['Quantity'].mode()
std_Quantity = df_sales['Quantity'].std()

mean_UnitPrice = df_sales['UnitPrice'].mean()
median_UnitPrice = df_sales['UnitPrice'].median()
mode_UnitPrice = df_sales['UnitPrice'].mode()
std_UnitPrice = df_sales['UnitPrice'].std()

print(f"Quantity - Mean: {mean_Quantity}, Median: {median_Quantity}, Mode: {mode_Quantity}, Std Dev: {std_Quantity}")
print(f"UnitPrice - Mean: {mean_UnitPrice}, Median: {median_UnitPrice}, Mode: {mode_UnitPrice}, Std Dev: {std_UnitPrice}")
# Out:
# Quantity - Mean: 13.610961009642518, Median: 6.0, Mode: 0    1
# Name: Quantity, dtype: int64, Std Dev: 261.57756533207146
# UnitPrice - Mean: 3.0835027678710816, Median: 1.95, Mode: 0    1.25
# Name: UnitPrice, dtype: float64, Std Dev: 5.177652565375899

# %% [markdown]
# ### Task 3: Merging DataFrames
# #### Objective: Merge the Sales, Invoice, and Product tables based on common keys to perform a comprehensive analysis.
#
# Instructions:
#
# 1. Merge the Sales DataFrame with the Invoice DataFrame on InvoiceNo.
#
# 2. Merge the result with the Product DataFrame on StockCode

# %%
## Code Task 3 here
import pandas as pd

df = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx")
df_sales = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx", sheet_name='Sales')

display(df_sales.head(10))

# %% [markdown]
# <mark>**--->>>TASK 3 #1**</mark>

# %%
import pandas as pd

df = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx")

df_sales = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx", sheet_name='Sales')
df_invoice = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx", sheet_name='Invoice')
df_product = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx", sheet_name='Product')

merge_df = pd.merge(df, df_invoice, on='InvoiceNo', how = 'left')
display(merge_df.head(10))

# %% [markdown]
# <mark>**--->>TASK 3 #2**</mark>

# %%
merge_df = pd.merge(df, df_product, on='StockCode', how = 'left')
display(merge_df.head(10))

# %% [markdown]
# ## Task 4: Exploratory Data Analysis (EDA)
# ### Objective: Conduct EDA by analysing the data, identifying patterns, trends, and outliers.
#
# Instructions:
#
# Use describe() to calculate summary statistics for numeric columns.
#
# Perform basic filtering, such as filtering out sales with Quantity equal to 0.
#
# Check for outliers in the Sales column by using a scatter plot.

# %%
## Code Task 4 here
import pandas as pd

df = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx")
print(df.describe().T)
# Out:
#                count                 mean                  min  \
# InvoiceNo    83277.0             550244.0             536365.0
# StockCode    83277.0          32948.77486              10002.0
# Quantity     83277.0            13.610961                  1.0
# UnitPrice    83277.0             3.083503                  0.0
# InvoiceDate    83277  2016-12-31 00:00:00  2015-01-01 00:00:00
#
#                              25%                  50%                  75%  \
# InvoiceNo               543304.0             550244.0             557184.0
# StockCode                21843.0              22470.0              22941.0
# Quantity                     2.0                  6.0                 12.0
# UnitPrice                   1.25                 1.95                 3.75
# InvoiceDate  2016-01-01 00:00:00  2016-12-31 00:00:00  2017-12-31 00:00:00
#
#                              max           std
# InvoiceNo               564123.0   8013.381169
# StockCode                90214.0  22938.831323
# Quantity                 74215.0    261.577565
# UnitPrice                  295.0      5.177653
# InvoiceDate  2018-12-31 00:00:00           NaN

# %% [markdown]
# Accessing the Sales column:

# %%
#Perform basic filtering, such as filtering out sales with Quantity equal to 0.
import pandas as pd

df = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx")
display(df.head(20))

# %%
df_sales = df['Quantity']
display(df_sales.head(20))

# %% [markdown]
# There is no data available.  It has found zero rows where the Quantity was equal to 0.

# %%
filtered_df = df[df['Quantity'] == 0]
display(filtered_df)

# %%
##Check for outliers in the Sales column by using a scatter plot.
import matplotlib.pyplot as plt
import seaborn as sns

df_sales = df['Quantity']

# Calculate Sales: 
df['Sales'] = df['Quantity'] * df['UnitPrice']

# Create the Scatter Plot
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df.index, y=df['Sales'], alpha=1.0)

plt.title('Scatter Plot of Sales', fontsize=15)
plt.xlabel('Transaction')
plt.ylabel('Sales Amount')

plt.show()

##
##(contd)

# %% [markdown]
# FOR SCATTER PLOT OF SALES: Based on the scatter plot, where 99% of data lives. It tells that almost all of 83,000+ transactions are for small amounts (between $1 and $500). There is one specific transaction where the total sales amount was massive compared to everything else. This represents the huge outlier shown in the code below with sales $77183.6

# %%
#This is the row that has a massic 77k sale:
huge_outlier = df[df['Sales'] > 70000]
print(huge_outlier)
# Out:
#        InvoiceNo  StockCode  Quantity  UnitPrice InvoiceDate    Sales
# 36980     548691      23166     74215       1.04  2016-10-10  77183.6

# %% [markdown]
# ## Task 5: Data Visualisation – Scatter Plot, Histogram, and Line Chart
# ### Objective: Create scatter plots, histograms, and line charts to better understand the data.
#
# Instructions:
#
# Use a scatter plot to examine the relationship between Quantity and Sales.
#
# Use a histogram to visualise the distribution of the Sales column.
#
# Use a line chart to show the trend of Sales over time.

# %%
## Code Task 5 here: Use a scatter plot to examine the relationship between Quantity and Sales.
import matplotlib.pyplot as plt
import seaborn as sns

# visual
plt.figure(figsize=(8, 5))
sns.set_style("dark")

#Scatter plot
#Put Quantity on X and Sales on Y
sns.scatterplot(data=df, x='Quantity', y='Sales', alpha=1.0, color='darkblue')

##Add: titles and labels
plt.title('Relationship Between Quantity and Sales', fontsize=12)
plt.xlabel('Quantity Ordered', fontsize=10)
plt.ylabel('Total Sales Amount ($)', fontsize=10)

# 4. Display
plt.show()

# %%
##Use a histogram to visualise the distribution of the Sales column.
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.set_style("dark")

#Histogram
sns.histplot(df['Sales'], bins=50, kde=True, color='skyblue')

plt.title('Distribution of Sales', fontsize=15)
plt.xlabel('Sales Value ($)')
plt.ylabel('Number of Transactions')

plt.show()

# %%
##Use a line chart to show the trend of Sales over time.
##Adding a new column to find the total Sales

import pandas as pd

df_sales = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx")
df_sales = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx", sheet_name='Sales')

df_sales['Total_Sales'] = df_sales['Quantity'] * df_sales['UnitPrice']

display(df_sales)

# %%
df_sales['InvoiceDate'] = pd.to_datetime(df_sales['InvoiceDate'])

sales_by_date = df_sales.groupby('InvoiceDate')['Total_Sales'].sum().reset_index()
display(sales_by_date)

# %%
##Line Chart
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_sales['InvoiceDate'] = pd.to_datetime(df_sales['InvoiceDate'])

sales_by_date = df_sales.groupby('InvoiceDate')['Total_Sales'].sum().reset_index()


plt.figure(figsize=(10,6))
sns.lineplot( x='InvoiceDate', y='Total_Sales', data = sales_by_date, marker = 'o', color = 'b')
plt.title('Trend of Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Total_Daily_Sales') 
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Task 6: Correlation and Data Insights
# ### Objective: Identify the relationship between different numerical columns in the dataset.
#
# Instructions:
#
# Calculate the correlation between Quantity and Sales.
#
# Visualise the correlation matrix using a heatmap.

# %%
## Code Task 6 here
correlation =df_sales[['Quantity', 'Total_Sales']].corr()

print(correlation)

plt.figure(figsize =(6,4))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix between Quantity and Total_Sales')
plt.show()
# Out:
#              Quantity  Total_Sales
# Quantity     1.000000     0.978609
# Total_Sales  0.978609     1.000000

# %% [markdown]
# ## Task 7: Grouping and Aggregating
# ### Objective: Perform grouping and aggregation operations to summarise the data.
#
# Instructions:
#
# GroupBy operation: Group by Product_Category and calculate the total Sales per category.
#
# Create a Pivot Table to show Sales by Country and Product_Category.

# %%
##merge using stockcode (product and sales sheets)
import pandas as pd
df = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx")
df_sales = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx", sheet_name='Sales')
df_invoice = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx", sheet_name='Invoice')
df_product = pd.read_excel(f"{notebookutils.nbResPath}/builtin/online_sales_retailer 5.xlsx", sheet_name='Product')


df_sales['Total_Sales'] = df_sales['Quantity'] * df_sales['UnitPrice']

df_merged = pd.merge(df_sales, df_product, on='StockCode', how = 'left')

df_final = pd.merge(df_merged, df_invoice, on='InvoiceNo', how='left')


category_sales = df_final.groupby('Product_Category')['Total_Sales'].sum().reset_index()

# %%
country_pivot = df_final.pivot_table(
    values='Total_Sales', 
    index='Country', 
    columns='Product_Category', 
    aggfunc='sum'
)

display(category_sales)
display(country_pivot)

# %%
pivot_summary = df_final.pivot_table(
    values='Total_Sales', 
    index='Country', 
    columns='Product_Category', 
    aggfunc='sum',
    fill_value=0  # This turns those NULLs into 0.00
)

display(pivot_summary)

sorted_summary = category_sales.sort_values(by='Total_Sales', ascending=False)
display(sorted_summary)

# %% [markdown]
# ## Submission Guidelines:
# Submit the Python notebook with all the tasks and visualisations.
#
# Ensure that each task is clearly explained and that all steps are followed.
#
# Include markdown explanations where necessary to explain your thought process.

# %% [markdown]
# Well done on the code, however I expect that you provide more explanation on your approach and insights after the outputs from the code. Jose
